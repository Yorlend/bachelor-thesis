# %%
import pstats

p = pstats.Stats('profile.prof')
p

# %%
p.sort_stats('cumtime').print_stats()
# Out:
# Mon May 20 21:12:17 2024    profile.prof
#
#          80560893 function calls (80489821 primitive calls) in 182.343 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.006    0.006  182.342  182.342 /home/yorlend/Projects/bachelor-thesis/backend/src/domain/optimizers/BoidsOptimizer.py:114(optimize)
#       550    0.002    0.000  181.187    0.329 /home/yorlend/Projects/bachelor-thesis/backend/src/domain/optimizers/BoidsOptimizer.py:33(evaluate)
#       550    7.726    0.014  181.185    0.329 /home/yorlend/Projects/bachelor-thesis/backend/src/domain/optimizers/BoidsOptimizer.py:175(f)
#   1320550   15.913    0.000  150.904    0.000 /home/yorlend/Projects/bachelor-thesis/backend/src/domain/methods/Gradient.py:41(predict)
#   1320550   75.635    0.000   86.636    0.000 /home/yorlend/Projects/bachelor-thesis/backend/src/domain/methods/Gradient.py:80(_get_closest_test_point)
# ...
